# %% [markdown]
# <a href="https://colab.research.google.com/github/euBRASIL/blocorrente/blob/master/Minerador.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import hashlib
import json
import sys
from tqdm import tqdm

# %%
pip install base58==2.1.1
# Out:
# Requirement already satisfied: base58==2.1.1 in /usr/local/lib/python3.10/dist-packages (2.1.1)

# %%
import base58

# %%
pip install ecdsa
# Out:
# Requirement already satisfied: ecdsa in /usr/local/lib/python3.10/dist-packages (0.18.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from ecdsa) (1.16.0)

# %%
import ecdsa

# %%
pip install ripemd-hash==1.0.1
# Out:
# Requirement already satisfied: ripemd-hash==1.0.1 in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
from ripemd.ripemd160 import ripemd160  # import function

# %%
pip install pyOpenSSL
# Out:
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (23.2.0)
# Requirement already satisfied: cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL) (2.21)

# %%
def calculate_match_percentage(str1, str2):
    len_str1 = len(str1)
    len_str2 = len(str2)

    min_len = min(len_str1, len_str2)
    matching_chars = sum(1 for c1, c2 in zip(str1, str2) if c1 == c2)

    return (matching_chars / min_len) * 100

# %%
def generate_bitcoin_keypair_range(start_hex, end_hex, target_address):
    start_int = int(start_hex, 16)
    end_int = int(end_hex, 16)
    step = 10000000  # Define o tamanho do passo para iterar de |10|000|000|

    max_match_percentage = 0
    max_match_address = ""

    resultados_json = []  # Lista para armazenar os resultados

    with open("29Porcento.txt", "a") as file:
        for batch_start in range(start_int, end_int + 1, step):
            batch_end = min(batch_start + step - 1, end_int)
# -------------------------------------------------------------------------------------------------------
# Loop para gerar o address do bitcoin, +1 << alterar >>
#-------------------------------------------------------
            for private_key_int in tqdm(range(batch_start, batch_end + 1), desc="Progresso", unit="chaves", file=sys.stdout):
                private_key_hex = format(private_key_int, 'x').zfill(64)
                private_key_bytes = bytes.fromhex(private_key_hex)
                sk = ecdsa.SigningKey.from_string(private_key_bytes, curve=ecdsa.SECP256k1)
                vk = sk.get_verifying_key()

                public_key_bytes = vk.to_string()
                sha256_hash = hashlib.sha256(public_key_bytes).digest()

                # h = ripemd160.new()
                ripemd160(b'abc').hex() == sha256_hash
                ripemd160_hash = bytes.fromhex(ripemd160(b'a' * 1000000).hex())

                extended_hash = b'\x00' + ripemd160_hash
                checksum = hashlib.sha256(hashlib.sha256(extended_hash).digest()).digest()[:4]
                address_bytes = extended_hash + checksum
                bitcoin_address = base58.b58encode(address_bytes).decode()

                match_percentage = calculate_match_percentage(target_address, bitcoin_address)
                if match_percentage > max_match_percentage:
                    max_match_percentage = match_percentage
                    max_match_address = bitcoin_address


                # if match_percentage > 26 and bitcoin_address.startswith("13"):
                print(f"\nChave Privada (hexadecimal): {private_key_hex}")
                print(f"Endereço Bitcoin: {bitcoin_address}")
                print(f"Percentual de Correspondência: {match_percentage:.2f}%\n")

# %%
print(hashlib.algorithms_available)
# Out:
# {'blake2s', 'sm3', 'sha384', 'md5-sha1', 'shake_128', 'sha3_384', 'sha3_224', 'sha512', 'sha512_256', 'sha3_512', 'shake_256', 'sha512_224', 'sha3_256', 'sha256', 'sha1', 'md5', 'sha224', 'blake2b'}

# %%
if __name__ == "__main__":
    initial_private_key_hex = "0000000000000000000000000000000000000000000000037777777777777777"
    final_private_key_hex =   "000000000000000000000000000000000000000000000003ffffffffffffffff"
    target_address = "13zb1hQbWVsc2S7ZTZnP2G4undNNpdh5so"

# %%
    generate_bitcoin_keypair_range(initial_private_key_hex, final_private_key_hex, target_address)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a70c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a70d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a70e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a70f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a710
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a711
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a712
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12188/10000000 [03:04<44:35:51, 62.21chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a713
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a714
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a715
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a716
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a717
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a718
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a719
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12195/10000000 [03:04<44:54:24, 61.78chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a71f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a720
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12202/10000000 [03:04<45:49:41, 60.54chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a721
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a722
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a723
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a724
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a725
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a726
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a727
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12209/10000000 [03:05<46:30:58, 59.64chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a728
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a729
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12216/10000000 [03:05<45:28:51, 61.00chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a72f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a730
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a731
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a732
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a733
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a734
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a735
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12223/10000000 [03:05<44:15:07, 62.69chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a736
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a737
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a738
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a739
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12230/10000000 [03:05<44:18:47, 62.61chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a73f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a740
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a741
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a742
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a743
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12237/10000000 [03:05<43:34:49, 63.66chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a744
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a745
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a746
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a747
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a748
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a749
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12244/10000000 [03:05<42:43:56, 64.92chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a74f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a750
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a751
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12251/10000000 [03:05<42:28:55, 65.31chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a752
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a753
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a754
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a755
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a756
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a757
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a758
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12258/10000000 [03:05<43:34:47, 63.66chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a759
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a75f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12265/10000000 [03:05<42:56:32, 64.61chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a760
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a761
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a762
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a763
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a764
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a765
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a766
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12272/10000000 [03:06<42:12:09, 65.74chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a767
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a768
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a769
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12279/10000000 [03:06<41:49:05, 66.34chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a76f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a770
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a771
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a772
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a773
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a774
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12286/10000000 [03:06<42:47:53, 64.82chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a775
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a776
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a777
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a778
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a779
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12293/10000000 [03:06<43:43:58, 63.44chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a77f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a780
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a781
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a782
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12300/10000000 [03:06<42:36:31, 65.11chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a783
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a784
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a785
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a786
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a787
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a788
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a789
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12307/10000000 [03:06<41:49:17, 66.34chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a78f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a790
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12314/10000000 [03:06<41:12:32, 67.32chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a791
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a792
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a793
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a794
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a795
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a796
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a797
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12321/10000000 [03:06<41:44:00, 66.48chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a798
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a799
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79a
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79b
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79c
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79d
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79e
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12328/10000000 [03:06<41:39:58, 66.59chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a79f
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12335/10000000 [03:06<42:08:57, 65.82chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7a9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7aa
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ab
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ac
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12342/10000000 [03:07<41:30:49, 66.83chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ad
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ae
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7af
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12349/10000000 [03:07<41:16:45, 67.21chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7b9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ba
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12356/10000000 [03:07<41:40:52, 66.56chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7bb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7bc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7bd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7be
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7bf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12363/10000000 [03:07<41:24:43, 66.99chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12370/10000000 [03:07<41:17:46, 67.18chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7c9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ca
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7cb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7cc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7cd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ce
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7cf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12377/10000000 [03:07<41:19:13, 67.14chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12384/10000000 [03:07<41:24:09, 67.01chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7d9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7da
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7db
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7dc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7dd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12391/10000000 [03:07<41:17:03, 67.20chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7de
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7df
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12398/10000000 [03:07<42:44:08, 64.92chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7e9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ea
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7eb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12405/10000000 [03:08<42:58:21, 64.56chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ec
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ed
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ee
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ef
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12412/10000000 [03:08<42:05:37, 65.91chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7f9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 12419/10000000 [03:08<41:49:27, 66.33chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7fa
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7fb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7fc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7fd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7fe
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777a7ff
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# ...
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaae
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaaf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13117/10000000 [03:19<41:29:33, 66.86chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aab9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaba
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13124/10000000 [03:19<40:58:51, 67.69chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aabb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aabc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aabd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aabe
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aabf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13131/10000000 [03:19<40:44:50, 68.08chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13138/10000000 [03:19<40:32:29, 68.43chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aac9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaca
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aacb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aacc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aacd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aace
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aacf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13145/10000000 [03:19<42:05:06, 65.92chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13152/10000000 [03:19<41:40:32, 66.56chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aad9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aada
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aadb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aadc
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aadd
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13159/10000000 [03:19<41:36:39, 66.67chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aade
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aadf
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae4
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13166/10000000 [03:19<41:33:45, 66.75chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae5
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae6
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae7
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae8
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aae9
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaea
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaeb
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13173/10000000 [03:20<41:02:01, 67.61chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaec
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaed
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaee
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaef
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaf0
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaf1
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
#
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaf2
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
#
# Progresso:   0%|          | 13180/10000000 [03:20<41:00:14, 67.65chaves/s]
# Chave Privada (hexadecimal): 000000000000000000000000000000000000000000000003777777777777aaf3
# Endereço Bitcoin: 18X4Q7t8yZeSrF6LE3WS5m2isrDTSPJ3Qx
# Percentual de Correspondência: 2.94%
# Progresso:   0%|          | 13180/10000000 [03:20<42:08:11, 65.84chaves/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-177718f205e6> in <cell line: 1>()
# ----> 1 generate_bitcoin_keypair_range(initial_private_key_hex, final_private_key_hex, target_address)
#
# <ipython-input-82-3681346b44d8> in generate_bitcoin_keypair_range(start_hex, end_hex, target_address)
#      42                 print(f"\nChave Privada (hexadecimal): {private_key_hex}")
#      43                 print(f"Endereço Bitcoin: {bitcoin_address}")
# ---> 44                 print(f"Percentual de Correspondência: {match_percentage:.2f}%\n")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
